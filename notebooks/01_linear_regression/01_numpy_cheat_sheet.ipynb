# %%
import numpy as np
import time

# %%
a = np.zeros(4);
b = np.zeros((4,));
print(f"np.zeros(4) : a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
print(f"np.zeros(4) : b = {b}, b shape = {b.shape}, b data type = {b.dtype}")

# %%
a = np.array([1, 2, 4, 7, 9])
b = np.array([1, 2.3, 4, 7, 9])

print(f"a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
print(f"b = {b}, b shape = {b.shape}, b data type = {b.dtype}")

# %% [markdown]
# # INDEXING

# %%
a = np.arange(10)
print(f"a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
print(f"a.shape = {a.shape[0]}")
print(f"a[-1] = {a[-3:]}")

# %% [markdown]
# # SLICING

# %%
a = np.arange(10)
print(f"a : {a}")

#access 5 consecutive elements (start:stop:step)
c = a[2:7:1]
print(f"c : {c}")
d = a[2:7:2]
print(f"d : {d}")

c = a[3:] # print all element starting from 3rd indext to last
print(f"a[3:] : {c}")

# %% [markdown]
# # Single Vector Operations

# %%
a = np.array([1, 2, 4, 7])

b = -a
print(f"b: {b}")

b = np.sum(a)
print(f"np.sum(a) = {b}")

c = np.mean(a)
print(f"mean of a : {c}")

d = a**2
print(f"a**2 = {d}")

# %% [markdown]
# # Vector vector element-wise opearation

# %%
a = np.array([1, 2, 3, 7])
b = np.array([3, 5, 8, 9])

print(f"binary ops a + b = {a+b}")

try:
    c = np.array([1, 2])
    d = a + c
except Exception as e:
    print("the error message :")
    print(e)

# %% [markdown]
# # Scalar Vector Operations

# %%
a = np.array([2, 3, 5, 7])
b = 5*a;
print(f"b: {b}")

# %% [markdown]
# ## Vector Vector Dot Product

# %%
def my_dot(a, b):
    x = 0
    for i in range (a.shape[0]):
        x = x + a[i]*b[i]
    return x

# %%
a = np.array([1,2, 3, 5]);
b = np.array([-1, 2, 4, 10]);

print(f"my_dot(a, b): {my_dot(a, b)}")

# %%
a = np.array([1,2, 3, 5]);
b = np.array([-1, 2, 4, 10]);
c = np.dot(a, b)
print(f"dot product of a and b is : {c}")

d = np.dot(b, a)
print(f"dot product of b and a is : {d}")

# %% [markdown]
# # Comparing Speed : Vector vs For Loop

# %%
np.random.seed(1)
a = np.random.rand(10000000)  # very large arrays
b = np.random.rand(10000000)

tic = time.time()
c = np.dot(a, b)
toc = time.time()
print(f"np.dot(a, b) = {c: .4f}")
print(f"vectorization version dot prod duration: {1000*(toc-tic): .4f} ms")


tic = time.time();
c = my_dot(a, b)
toc = time.time();
print(f"my_dot(a, b) = {c: .4f}")
print(f"For loop version dot prod duration: {1000*(toc-tic): .4f} ms")
del(a);del(b)  #remove these big arrays from memory

# %% [markdown]
# # Matrices

# %%
a = np.zeros((2, 5))
print(f"a = {a}")

a = np.random.random_sample((2, 2))
print(f"a shape = {a.shape}, a = {a}")

# %%
a = np.array([[5, 3, 2], [3, 9, 8]])
print(f"a = {a}")

# %% [markdown]
# # Operation on Matrices

# %%
#vector indexing operations on matrices
a = np.arange(6).reshape(-1, 2)   #reshape is a convenient way to create matrices
print(f"a.shape: {a.shape}, \na= {a}")

#access an element
print(f"\na[2,0].shape:   {a[2, 0].shape}, a[2,0] = {a[2, 0]},     type(a[2,0]) = {type(a[2, 0])} Accessing an element returns a scalar\n")

#access a row
print(f"a[2].shape:   {a[2].shape}, a[2]   = {a[2]}, type(a[2])   = {type(a[2])}")

# %% [markdown]
# **Reshape**
# The previous example used [reshape](https://numpy.org/doc/stable/reference/generated/numpy.reshape.html) to shape the array.
# `a = np.arange(6).reshape(-1, 2) `
# This line of code first created a *1-D Vector* of six elements. It then reshaped that vector into a *2-D* array using the reshape command. This could have been written:
# `a = np.arange(6).reshape(3, 2) `
# To arrive at the same 3 row, 2 column array.
# The -1 argument tells the routine to compute the number of rows given the size of the array and the number of columns.

# %% [markdown]
# # Slicing

# %%
#vector 2-D slicing operations
a = np.arange(20).reshape(-1, 10)
print(f"a = \n{a}")

#access 5 consecutive elements (start:stop:step)
print("a[0, 2:7:1] = ", a[0, 2:7:1], ",  a[0, 2:7:1].shape =", a[0, 2:7:1].shape, "a 1-D array")

#access 5 consecutive elements (start:stop:step) in two rows
print("a[:, 2:7:1] = \n", a[:, 2:7:1], ",  a[:, 2:7:1].shape =", a[:, 2:7:1].shape, "a 2-D array")

# access all elements
print("a[:,:] = \n", a[:,:], ",  a[:,:].shape =", a[:,:].shape)

# access all elements in one row (very common usage)
print("a[1,:] = ", a[1,:], ",  a[1,:].shape =", a[1,:].shape, "a 1-D array")
# same as
print("a[1]   = ", a[1],   ",  a[1].shape   =", a[1].shape, "a 1-D array")
